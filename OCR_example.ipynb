# %%
import pytesseract


pytesseract.pytesseract.tesseract_cmd=r'C:\\Program Files\\Tesseract-OCR\\tesseract'
import cv2
import matplotlib.pyplot as plt


image = cv2.imread('.\\OcrText\\text5.jpg') # image read
#image = cv2.imread('./\\OcrText\\text2.jpg') # image read

img2 = image.copy()
img2= image[0:100,800:1250] # y,x
#img2= image[0:200,0:300] # y,x

cv2.imshow("dd",img2)
cv2.waitKey(0)
cv2.destroyAllWindows()
img = cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY) #convert BGR -> GRAY opencv 이용하여 이미지 불러올시 RGB가 아니라 BGR로 불러옴
#ret,img = cv2.threshold(img, 170, 255, cv2.THRESH_BINARY)
img = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)[1]
#cv2.threshold()
# img = 원본 이미지
# 0 = 임계값
# 255 = 임계값 이상일 경우 바꿀 최대값(보통 흰색인 255로 지정)
# cv2.THRESH_BINARY  = 픽셀값이 임계값보다 클 경우 최대값으로 하고 픽셀값이 임계값보다 작은경우 0으로 이진화
# cv2.THRESH_OTSU 를 추가로 적용하면 임계값을 자동으로 계산해줌



#img= cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 21, 5)
#img= cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 21, 5)


plt.imshow(img,cmap='gray')        #cmap 이미지 gray로 출력


c=pytesseract.image_to_string(img,config='-l eng+kor --oem 3 --psm 4')

print(c)
# Out:
# 2018/08/14 11:40:14

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r'C:\\Program Files\\Tesseract-OCR\\tesseract'
import cv2
font = cv2.FONT_HERSHEY_PLAIN
cap = cv2.VideoCapture("cctv.mp4")

print(cap.get(cv2.CAP_PROP_FPS))

w = round(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
fourcc = cv2.VideoWriter_fourcc(*'DIVX')


while cap.isOpened():
    success,frame = cap.read()
    if success:
        print(cap.get(1))
        img2 = frame.copy()
        img2= frame[0:100,800:1250] # y,x
        #img2= frame[0:200,0:300] # y,x
        img = cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY) #convert BGR -> GRAY opencv 이용하여 이미지 불러올시 RGB가 아니라 BGR로 불러옴

        
        print(type(img))
        img = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
        c=pytesseract.image_to_string(img,config='-l eng --oem 3 --psm 4')

        print(c)
        cv2.imshow('test',frame)
        
        if cv2.waitKey(30)&0xFF == 27: 
            break #자원 메모리 해제 
    else :
        break
            
cap.release()
cv2.destroyAllWindows()
# Out:
# 30.0
# 1.0
# <class 'numpy.ndarray'>
# ) ME, a VO, a\. oS nae
# , een 11; 385008
# ? ae
#
# 2.0
# <class 'numpy.ndarray'>
# |) ME, AO, a\. oS nae
# 5 Meg SE it 3es08.
# ” ee
#
# 3.0
# <class 'numpy.ndarray'>
# |) ME, ATO, a\. oS nae
# , een 11 3809
# 4 ee
#
# 4.0
# <class 'numpy.ndarray'>
# | MR, AON, a\. oS nas
# 5 Meg OE it 3es00
# + ee
#
# 5.0
# <class 'numpy.ndarray'>
# 0 ee, ae AVP 4 4\: 28 caac
# 9s ees
#
# 6.0
# <class 'numpy.ndarray'>
# | ve nO) |. we
# 9s ees
#
# 7.0
# <class 'numpy.ndarray'>
# 0 ee we TAI 4 4\: 20 ne
# 9s eee
#
# 8.0
# <class 'numpy.ndarray'>
# 9 ee 1: 3806
# ) eee
#
# 9.0
# <class 'numpy.ndarray'>
# 9s ees
# +] eet
#
# 10.0
# <class 'numpy.ndarray'>
# ee, ae FAV 4 4\: 22 -nche
# 9s eles
#
# 11.0
# <class 'numpy.ndarray'>
# { va AMON |. 3"
# 9s eae
#
# 12.0
# <class 'numpy.ndarray'>
# { ee AMON |."
# 5 Meg OE it sew.
#
# 13.0
# <class 'numpy.ndarray'>
# { ee AMO |.
# 9s eles
#
# 14.0
# <class 'numpy.ndarray'>
# Bee jae Tale 4 4\: 22-046
# > Meg OE i sew.
#
# ...
